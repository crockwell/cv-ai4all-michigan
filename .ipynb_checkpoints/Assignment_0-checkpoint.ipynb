# %% [markdown]
# # Assignment 0: Computer Vision Basics in Python

# %% [markdown]
# Step 1: Let's begin with a printing test. Print the words "Hello World!".

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Step 2: Before we can practice computer vision techniques, we need an image to work with. Go online and find a good one.

# %% [markdown]
# Step 3: Now let's read in your image as a variable. That is, we're giving Python the path to our image, and expressing the image in a format that Python understands.

# %%
import numpy as np
import cv2 

# Load a color image
img = cv2.imread('michigan_squirrel.jpeg',1)
# Check out the documentation for the imread() function at: https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_gui/py_image_display/py_image_display.html

# %% [markdown]
# Step 4: Now let's display your test image.

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %% [markdown]
# Step 5: Let's convert that image to grayscale and display it again. When we're working with images, this is often a really useful conversion. A color image takes up a lot of data: each RGB (red, green, blue color) channel contains an entire matrix of data that we might not necessarily need. So, we compress it to shades of grey.

# %%
grey_img = cv2.cvtColor( img, cv2.COLOR_RGB2GRAY )
plt.imshow(grey_img, cmap='gray')
plt.show()

# %% [markdown]
# Step 6: Now let's save the grayscale image.

# %%
cv2.imwrite( "grey.png", grey_img )
# Out:
# True

# %% [markdown]
# Step 7: The grayscale image has been stored as a 2-D array (a matrix), whose entries give intensity values (the level of "grayness" at each pixel). Let's check the size of this matrix.

# %%
[h, w] = np.shape(grey_img)
print('The width of the image is:', w, '\nThe height of the image is:', h)
# Out:
# The width of the image is: 4032
# The height of the image is: 3024

# %% [markdown]
# Step 8: Let's try to rescale the grayscale image to arbitary height and width.

# %%
grey_img_new = cv2.resize(grey_img, (600, 400))
plt.imshow(grey_img_new, cmap='gray')
plt.show()
[h_new, w_new] = np.shape(grey_img_new)
print('The width of the new image is:', w_new, '\nThe height of the new image is:', h_new)
# Out:
# The width of the new image is: 600
# The height of the new image is: 400

# %% [markdown]
# Step 9: Let's practice thinking about this image as a matrix. First, extract one *row* of the matrix. Let's choose a row near the middle of the image.

# %%
row_num = 400
img_row = grey_img[400,:]

# %% [markdown]
# Step 10: Now, plot the intensity values along that row.
#
# Note: notice how the intensity values range between 0 (black) and 255 (white). Since 256 = 2^8, having 256 intensity options allows us to represent the color of each pixel with 8 bits (one byte) of information. It's an information-efficient binary encoding!

# %%
plt.plot(img_row)
plt.title('Intensity values along row ' + str(row_num))
plt.xlabel('Pixel value')
plt.ylabel('Intensity value')
plt.show()

# %% [markdown]
# Step 11: Which row did we analyze again? Let's knock out the intensity values in the vicinity of that row on the image, and display the image again.
#
# Can you see the corresponding low- and high-intensity regions along this strip?

# %%
row_missing = grey_img.copy()
row_missing[row_num-10:row_num+10,:] = 0
plt.imshow(row_missing,cmap='gray')
plt.show()

# %% [markdown]
# Step 12: Now let's draw black vertical stripes on the image after every 20 pixels. Use a for loop to do this, by zero-ing out pixel values as before. Let's also save the image so that we can open the image separately and verify that the stripes are correct.

# %%
stripes_img = grey_img.copy()
for i in range(0, w, 20):
    stripes_img[:,i]=0
cv2.imwrite( "stripes.png", stripes_img )
plt.imshow(stripes_img,cmap='gray')
plt.show()

# %% [markdown]
# Step 13: Find the *index* of the pixel along your chosen row with the maximum intensity value.

# %%
np.argmax(img_row)
# Out:
# 3994

# %% [markdown]
# Step 14: Now, flip the grayscale image upside-down!

# %%
flipped_img = np.flipud(grey_img)
plt.imshow(flipped_img,cmap='gray')
plt.show()

# %% [markdown]
# Step 15: Use matplotlib to plot the original colored image and the flipped grayscale image side-by-side.

# %%
plt.subplot(121)
plt.imshow(img)
plt.axis('off')
plt.subplot(122)
plt.imshow(flipped_img,cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Step 16: Now, let's read in this new image, "rice.png", as a grayscale image. We're going to practice thresholding.

# %%
rice_img = cv2.imread('rice.png',0)
plt.imshow(rice_img, cmap='gray')
plt.show()

# %% [markdown]
# Step 17: We wish to separate the grains of rice in the foreground of this image from the darker background. So, we will "threshold" the image: that is, we choose an intensity value. Everything below this value is considered to be background, and everything above this value is considered to be foreground. Thus, we get a *binary mask*. Play around with different threshold values for comparison.

# %%
threshold_value =  130
ret,thresh1 = cv2.threshold(rice_img,threshold_value,255,cv2.THRESH_BINARY)
plt.imshow(thresh1)
plt.show()

# %% [markdown]
# Step 18: Now try thresholding your own image. What happens?

# %%
threshold_value =  130
ret,thresh1 = cv2.threshold(grey_img,threshold_value,255,cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')
plt.show()

# %% [markdown]
# Not so nice! Let's reconvene and discuss some of the challenges in computer vision.
